# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
df_2023 = pd.read_csv('../Data/2023_NCAA_Players.csv')

# %%
df_2024 = pd.read_csv('../Data/2024_NCAA_Players.csv')

# %%
df_2023
# Out:
#                  Player               Team Conference  GP   MPG   ORtg   USG  \
# 0         Jailyn Ingram            Georgia        SEC  24  19.6   91.2  19.5
# 1       Deandre Dishman   Middle Tennessee       CUSA  31  68.6  102.8  24.4
# 2        DeJuan Clayton         California        P12   9  22.0   84.6  21.9
# 3       Brevin Galloway            Clemson        ACC  32  68.2  108.6  20.0
# 4          Michael Henn           Penn St.        B10  29  16.6  107.5  17.4
# ...                 ...                ...        ...  ..   ...    ...   ...
# 5038        Mady Traore     New Mexico St.        WAC   7   6.1  111.8   9.0
# 5039      Steven Tipton  Northern Illinois        MAC   2   0.2    0.0  13.8
# 5040     Uchenna Ndigwe       San Jose St.        MWC   1   0.1    0.0   0.0
# 5041  Patrick Gallagher          San Diego        WCC   1   0.3   26.4  45.6
# 5042    Stephen Boateng               Iona       MAAC   1   0.1  119.3  20.0
#
# ...

# %%
df_2024
# Out:
#                       Player                    Team Conference  GP   MPG  \
# 0                 Seth Towns                  Howard       MEAC  19  68.7
# 1             Terrence Lewis           Grambling St.       SWAC  15  36.1
# 2            Austin Williams                 Rutgers        B10  17  34.5
# 3               Avery Wilson  Southeastern Louisiana       Slnd  20  31.5
# 4               Jalen Jordan        Middle Tennessee       CUSA  17  38.8
# ...                      ...                     ...        ...  ..   ...
# 4946  Yulian Ramirez-Montero                    UMKC        Sum  12  20.2
# 4947            JaVar Daniel             Austin Peay       ASun   7   6.7
# 4948             Tyler Mason           Massachusetts        A10   3   1.3
# 4949            Bencau Vungo           East Carolina       Amer   3   3.3
# 4950            Damien Mazil                  Wagner        NEC   1   0.1
#
#        ORtg   USG   eFG%     TS%  ORB%  ...     DG_BPM  OREB_PG  DREB_PG  \
# ...
